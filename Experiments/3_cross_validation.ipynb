# %% [markdown]
# ### K-Fold Cross Validation

# %%
import pandas as pd
from sklearn.model_selection import KFold
# Out:
# /Users/sakthi/opt/anaconda3/envs/ml/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv("Datasets/winequality-red.csv", index_col=None)
df.shape
# Out:
# (1599, 12)

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.7              0.23         0.37             1.8      0.046
# 1            6.2              0.46         0.17             1.6      0.073
# 2            8.9              0.59         0.39             2.3      0.095
# 3            6.6              0.84         0.03             2.3      0.059
# 4            7.4              0.61         0.01             2.0      0.074
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 23.0                  60.0  0.99710  3.41       0.71
# 1                  7.0                  11.0  0.99425  3.61       0.54
# 2                  5.0                  22.0  0.99860  3.37       0.58
# 3                 32.0                  48.0  0.99520  3.52       0.56
# 4                 13.0                  38.0  0.99748  3.48       0.65
#
#    alcohol  quality
# 0     12.1        6
# 1     11.4        5
# 2     10.3        5
# 3     12.3        7
# 4      9.8        5

# %%
kf = KFold(n_splits=5)

# ## The below code is just to understand how kf.split works.
# kf = KFold(n_splits=3) # Create 3 splits of train and test sets
# # Now, the return of kf.split is 3 training and testing sample sets. 
# The values in the val/test set would be equal to number_of_samples_in_df/n_splits. Here, 1599/5=319
# Therefore, each validation set would have 319 non-overlapping samples. 
# The train set for each sample would contain df - (samples in val set)
# This way, the model trains on a sample of training dataset and evaluates on another sample of validation dataset that it has not seen during training
# NOTE: The training sets would be overlapping while the validation sets would be non-overlapping
# (tr1, te1), (tr2, te2) , (tr3, te3)= kf.split(X=df)

# %%
for fold, (train_, val_) in enumerate(kf.split(X=df)):
    df['kfold'][val_] = fold
# Out:
# /Users/sakthi/opt/anaconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.7              0.23         0.37             1.8      0.046
# 1            6.2              0.46         0.17             1.6      0.073
# 2            8.9              0.59         0.39             2.3      0.095
# 3            6.6              0.84         0.03             2.3      0.059
# 4            7.4              0.61         0.01             2.0      0.074
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 23.0                  60.0  0.99710  3.41       0.71
# 1                  7.0                  11.0  0.99425  3.61       0.54
# 2                  5.0                  22.0  0.99860  3.37       0.58
# 3                 32.0                  48.0  0.99520  3.52       0.56
# 4                 13.0                  38.0  0.99748  3.48       0.65
#
#    alcohol  quality  kfold
# 0     12.1        6      0
# 1     11.4        5      0
# 2     10.3        5      0
# 3     12.3        7      0
# 4      9.8        5      0

# %%
df.kfold.unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df.to_csv("Datasets/output_datasets/train_k_folds.csv", index=False)

# %% [markdown]
# K-Fold Cross Validation can be used when we have a balanced dataset with almost equal samples for all the categories.
# But, if the dataset is unbalanced, then we can't use K-Fold Cross Validation. Instead, we have to use Stratified K-Fold Cross Validation.

# %% [markdown]
# ### Stratified K-Fold Cross Validation

# %% [markdown]
# Stratified K-Fold Cross Validation keeps the ratio of target labels in each of the fold constant. This helps while dealing with imbalanced datasets.

# %%
from sklearn.model_selection import StratifiedKFold
import pandas as pd

# %%
df = pd.read_csv("Datasets/customer_churn_prediction_2020.csv", index_col=None)
df.shape
# Out:
# (4250, 20)

# %%
df = df.sample(frac=1).reset_index(drop=True)
df.head(3)
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    CT             107  area_code_408                 no              no
# 1    NC             102  area_code_408                 no             yes
# 2    WV              74  area_code_408                 no              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                      0               90.7               90
# 1                     27              109.8               66
# 2                      0              176.1               79
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             15.42              207.5              109             17.64
# 1             18.67              207.3               76             17.62
# 2             29.94              208.3              105             17.71
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                169.4                 96                7.62
# 1                236.9                101               10.66
# 2                237.5                 86               10.69
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                 5.6                 5               1.51
# 1                10.3                 7               2.78
# 2                16.1                 4               4.35
#
#    number_customer_service_calls churn
# 0                              2    no
# 1                              0    no
# 2                              4    no

# %%
df.churn.value_counts()
# We can see that the dataset is imbalanced
# Out:
# no     3652
# yes     598
# Name: churn, dtype: int64

# %%
skf = StratifiedKFold(n_splits=5)

# df['skfold'] = -1 # Not sure why this wasn't necessary while doing K-Fold Cross Validation

for fold, (train_, val_) in enumerate(skf.split(X=df, y=df.churn.values)):
    df['skfold'][val_] = fold
# Out:
# /Users/sakthi/opt/anaconda3/envs/ml/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.to_csv("Datasets/output_datasets/train_s_k_folds.csv")

# %%
df.head(3)
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    CT             107  area_code_408                 no              no
# 1    NC             102  area_code_408                 no             yes
# 2    WV              74  area_code_408                 no              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                      0               90.7               90
# 1                     27              109.8               66
# 2                      0              176.1               79
#
#    total_day_charge  total_eve_minutes  ...  total_eve_charge  \
# 0             15.42              207.5  ...             17.64
# 1             18.67              207.3  ...             17.62
# 2             29.94              208.3  ...             17.71
#
#    total_night_minutes  total_night_calls  total_night_charge  \
# 0                169.4                 96                7.62
# 1                236.9                101               10.66
# 2                237.5                 86               10.69
#
#    total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                 5.6                 5               1.51
# 1                10.3                 7               2.78
# 2                16.1                 4               4.35
#
#    number_customer_service_calls  churn skfold
# 0                              2     no      0
# 1                              0     no      0
# 2                              4     no      0
#
# [3 rows x 21 columns]

# %%
df.skfold.unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df.loc[df.skfold == 0]
# Out:
#     state  account_length      area_code international_plan voice_mail_plan  \
# 0      CT             107  area_code_408                 no              no
# 1      NC             102  area_code_408                 no             yes
# 2      WV              74  area_code_408                 no              no
# 3      AZ              72  area_code_510                 no              no
# 4      AK              52  area_code_510                 no              no
# ..    ...             ...            ...                ...             ...
# 849    RI             155  area_code_408                yes              no
# 850    NJ             100  area_code_415                 no              no
# 851    CT             112  area_code_415                 no             yes
# 852    NV              93  area_code_408                 no              no
# 853    OR              25  area_code_408                 no              no
#
#      number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                        0               90.7               90
# 1                       27              109.8               66
# 2                        0              176.1               79
# 3                        0              272.4               88
# 4                        0              148.3               83
# ..                     ...                ...              ...
# 849                      0              163.1               94
# 850                      0              203.8              122
# 851                     27              213.0              121
# 852                      0              114.3              100
# 853                      0              178.8               90
#
#      total_day_charge  total_eve_minutes  ...  total_eve_charge  \
# 0               15.42              207.5  ...             17.64
# 1               18.67              207.3  ...             17.62
# 2               29.94              208.3  ...             17.71
# 3               46.31              107.9  ...              9.17
# 4               25.21              181.6  ...             15.44
# ..                ...                ...  ...               ...
# 849             27.73              291.7  ...             24.79
# 850             34.65              283.1  ...             24.06
# 851             36.21              226.2  ...             19.23
# 852             19.43              221.1  ...             18.79
# 853             30.40              141.2  ...             12.00
#
#      total_night_minutes  total_night_calls  total_night_charge  \
# 0                  169.4                 96                7.62
# 1                  236.9                101               10.66
# 2                  237.5                 86               10.69
# 3                  185.5                 81                8.35
# 4                  155.6                104                7.00
# ..                   ...                ...                 ...
# 849                 96.4                111                4.34
# 850                197.3                 83                8.88
# 851                189.8                 99                8.54
# 852                126.3                 88                5.68
# 853                203.0                 99                9.14
#
#      total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                   5.6                 5               1.51
# 1                  10.3                 7               2.78
# 2                  16.1                 4               4.35
# 3                  12.7                 2               3.43
# 4                   8.3                 6               2.24
# ..                  ...               ...                ...
# 849                11.2                 3               3.02
# 850                12.5                 3               3.38
# 851                11.1                 3               3.00
# 852                10.9                 9               2.94
# 853                 8.4                 5               2.27
#
#      number_customer_service_calls  churn skfold
# 0                                2     no      0
# 1                                0     no      0
# 2                                4     no      0
# 3                                0     no      0
# 4                                3     no      0
# ..                             ...    ...    ...
# 849                              0     no      0
# 850                              0     no      0
# 851                              4     no      0
# 852                              0     no      0
# 853                              2     no      0
#
# [850 rows x 21 columns]

# %%
# Now, lets ensure that each fold has equal ratio of yes and no values for churn

print(df.loc[df.skfold == 0].churn.value_counts())
# Out:
# no     731
# yes    119
# Name: churn, dtype: int64

# %%
print(df.loc[df.skfold == 1].churn.value_counts())
# We can see that the ratio of yes:no remains the same for all folds. Thus, Stratified K Fold can be used while working with imbalanced datasets.
# Out:
# no     731
# yes    119
# Name: churn, dtype: int64
